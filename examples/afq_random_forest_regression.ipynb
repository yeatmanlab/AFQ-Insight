# %%
import afq_transform as afqt
import itertools
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, make_scorer, roc_auc_score
from sklearn.pipeline import Pipeline
# Out:
# /Users/Adam/anaconda/lib/python3.5/site-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
nodes = pd.read_csv('data/nodes.csv')
targets = pd.read_csv('data/subjects.csv', index_col='subjectID').drop(['Unnamed: 0'], axis='columns')
targets
# Out:
#              ALSFRS  ALSFRSbulbar  age class  diseaseduration gender
# subjectID
# subject_000      33            12   54   ALS               10      F
# subject_001      18             8   69   ALS               36      M
# subject_002      27             9   55   ALS               23      F
# subject_003      32            12   52   ALS               15      M
# subject_004      19             4   58   ALS                6      F
# subject_005      33             8   67   ALS               48      F
# subject_006      21             5   43   ALS                5      M
# subject_007      38             8   67   ALS                3      M
# subject_008      29             9   65   ALS               15      M
# subject_009      25             9   72   ALS                1      F
# subject_010      33             9   43   ALS               24      M
# subject_011      30             9   60   ALS               24      M
# subject_012      21             9   71   ALS                6      F
# subject_013      20             5   53   ALS                9      F
# subject_014      18            10   62   ALS               12      M
# subject_015      37            12   58   ALS                6      M
# subject_016      33            10   48   ALS               24      F
# subject_017      29            12   59   ALS                9      F
# subject_018      15             7   76   ALS               63      F
# subject_019      24             8   67   ALS                6      M
# subject_020      25             9   63   ALS               36      F
# subject_021      34             7   72   ALS                6      F
# subject_022      34             9   66   ALS               68      F
# subject_023      35            12   55   ALS                5      M
# subject_024       0             0   77  CTRL                0      F
# subject_025       0             0   71  CTRL                0      M
# subject_026       0             0   63  CTRL                0      M
# subject_027       0             0   59  CTRL                0      F
# subject_028       0             0   63  CTRL                0      F
# subject_029       0             0   50  CTRL                0      F
# subject_030       0             0   70  CTRL                0      M
# subject_031       0             0   69  CTRL                0      M
# subject_032       0             0   63  CTRL                0      F
# subject_033       0             0   62  CTRL                0      F
# subject_034       0             0   64  CTRL                0      F
# subject_035       0             0   59  CTRL                0      F
# subject_036       0             0   58  CTRL                0      F
# subject_037       0             0   65  CTRL                0      F
# subject_038       0             0   55  CTRL                0      M
# subject_039       0             0   54  CTRL                0      F
# subject_040       0             0   59  CTRL                0      F
# subject_041       0             0   43  CTRL                0      M
# subject_042       0             0   40  CTRL                0      M
# subject_043       0             0   60  CTRL                0      M
# subject_044       0             0   67  CTRL                0      F
# subject_045       0             0   64  CTRL                0      F
# subject_046       0             0   63  CTRL                0      F
# subject_047       0             0   58  CTRL                0      M

# %%
transformer = afqt.AFQFeatureTransformer()
x, groups, cols = transformer.transform(nodes)

# %%
label_sets = afqt.multicol2sets(cols)
label_sets
# Out:
# array([{'0', 'Callosum Forceps Major', 'ad'},
#        {'Callosum Forceps Major', 'ad', '1'},
#        {'2', 'Callosum Forceps Major', 'ad'}, ...,
#        {'Right Uncinate', 'Uncinate', 'volume', '97'},
#        {'Right Uncinate', 'Uncinate', 'volume', '98'},
#        {'Right Uncinate', 'Uncinate', 'volume', '99'}], dtype=object)

# %%
metric_idx = cols.names.index('metric')
tract_idx = cols.names.index('tractID')

tracts_and_metrics = list(
    itertools.product(cols.levels[metric_idx], cols.levels[tract_idx])
)

tracts_only = [(x, ) for x in cols.levels[tract_idx]]

handed_tracts = [x for x in tracts_only if 'Left' in x[0] or 'Right' in x[0]]

tracts_symm = list(set([
    (x[0].replace('Left ', '').replace('Right ', ''), )
    for x in handed_tracts
]))

group_labels = tracts_and_metrics + tracts_symm + tracts_only

# %% [markdown]
# # Get the feature group importances for classifying the subject class

# %%
y = targets['ALSFRS'].values
y = y[y > 0]
x = x[y > 0]
y
# Out:
# /Users/Adam/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: boolean index did not match indexed array along dimension 0; dimension is 48 but corresponding boolean dimension is 24
#   app.launch_new_instance()
# array([33, 18, 27, 32, 19, 33, 21, 38, 29, 25, 33, 30, 21, 20, 18, 37, 33,
#        29, 15, 24, 25, 34, 34, 35])

# %%
importances = afqt.get_random_forest_group_scores(
    x, y, group_labels, label_sets, type='regressor', n_splits=100
)
# Out:
# 100%|██████████| 100/100 [06:57<00:00,  4.18s/it]

# %%
for idx, (f, s) in enumerate(importances):
    print('{idx:03d}. {i:+7.5f} : {f!s}'.format(idx=idx+1, i=s, f=f))
# Out:
# 001. +0.02770 : ('Corticospinal',)
# 002. +0.01998 : ('SLF',)
# 003. +0.01940 : ('IFOF',)
# 004. +0.01428 : ('Left Corticospinal',)
# 005. +0.01413 : ('ILF',)
# 006. +0.01406 : ('Left IFOF',)
# 007. +0.01305 : ('Left SLF',)
# 008. +0.01079 : ('Arcuate',)
# 009. +0.00896 : ('Right SLF',)
# 010. +0.00734 : ('Right Corticospinal',)
# 011. +0.00595 : ('rd', 'Left Corticospinal')
# 012. +0.00585 : ('md', 'Left IFOF')
# 013. +0.00580 : ('ad', 'Left IFOF')
# 014. +0.00489 : ('Right Arcuate',)
# 015. +0.00442 : ('Left Cingulum Hippocampus',)
# 016. +0.00419 : ('Right Thalamic Radiation',)
# 017. +0.00418 : ('rd', 'Left ILF')
# 018. +0.00397 : ('Left ILF',)
# 019. +0.00389 : ('curvature', 'Left IFOF')
# 020. +0.00365 : ('curvature', 'Right SLF')
# 021. +0.00365 : ('cl', 'Left SLF')
# 022. +0.00360 : ('md', 'Left Arcuate')
# 023. +0.00359 : ('md', 'Left Corticospinal')
# 024. +0.00355 : ('Thalamic Radiation',)
# 025. +0.00312 : ('ad', 'Left SLF')
# 026. +0.00302 : ('Right ILF',)
# 027. +0.00297 : ('torsion', 'Left ILF')
# 028. +0.00290 : ('md', 'Left SLF')
# 029. +0.00287 : ('md', 'Right Corticospinal')
# 030. +0.00284 : ('volume', 'Right Thalamic Radiation')
# 031. +0.00284 : ('volume', 'Left Cingulum Cingulate')
# 032. +0.00281 : ('Right IFOF',)
# 033. +0.00272 : ('cl', 'Right Arcuate')
# 034. +0.00260 : ('rd', 'Right Corticospinal')
# 035. +0.00260 : ('cl', 'Right Corticospinal')
# 036. +0.00243 : ('ad', 'Right SLF')
# 037. +0.00240 : ('Callosum Forceps Minor',)
# 038. +0.00240 : ('rd', 'Right Cingulum Hippocampus')
# 039. +0.00238 : ('ad', 'Left Cingulum Hippocampus')
# 040. +0.00235 : ('fa', 'Callosum Forceps Minor')
# 041. +0.00229 : ('ad', 'Right Corticospinal')
# 042. +0.00225 : ('md', 'Left Cingulum Hippocampus')
# 043. +0.00223 : ('fa', 'Right SLF')
# 044. +0.00223 : ('curvature', 'Left ILF')
# 045. +0.00221 : ('cl', 'Right Cingulum Cingulate')
# 046. +0.00215 : ('curvature', 'Right ILF')
# 047. +0.00215 : ('ad', 'Right Uncinate')
# 048. +0.00200 : ('fa', 'Right ILF')
# 049. +0.00200 : ('torsion', 'Left Cingulum Hippocampus')
# 050. +0.00197 : ('cl', 'Left Thalamic Radiation')
# 051. +0.00196 : ('fa', 'Left Thalamic Radiation')
# 052. +0.00196 : ('volume', 'Right Arcuate')
# 053. +0.00193 : ('torsion', 'Left IFOF')
# 054. +0.00189 : ('torsion', 'Right Arcuate')
# 055. +0.00187 : ('md', 'Right ILF')
# 056. +0.00180 : ('md', 'Right Thalamic Radiation')
# 057. +0.00168 : ('torsion', 'Left Corticospinal')
# 058. +0.00166 : ('rd', 'Left Cingulum Hippocampus')
# 059. +0.00160 : ('md', 'Right Arcuate')
# 060. +0.00157 : ('rd', 'Left SLF')
# 061. +0.00153 : ('volume', 'Left Corticospinal')
# 062. +0.00147 : ('ad', 'Right Thalamic Radiation')
# 063. +0.00146 : ('curvature', 'Right Uncinate')
# 064. +0.00144 : ('curvature', 'Callosum Forceps Major')
# 065. +0.00134 : ('fa', 'Left Corticospinal')
# 066. +0.00132 : ('curvature', 'Right Cingulum Hippocampus')
# 067. +0.00128 : ('md', 'Callosum Forceps Major')
# 068. +0.00123 : ('cl', 'Right SLF')
# 069. +0.00120 : ('cl', 'Right IFOF')
# 070. +0.00117 : ('rd', 'Left Cingulum Cingulate')
# 071. +0.00114 : ('md', 'Right Cingulum Cingulate')
# 072. +0.00110 : ('fa', 'Left IFOF')
# 073. +0.00110 : ('rd', 'Left Arcuate')
# 074. +0.00108 : ('torsion', 'Right IFOF')
# 075. +0.00106 : ('Left Thalamic Radiation',)
# 076. +0.00103 : ('fa', 'Right Corticospinal')
# 077. +0.00103 : ('fa', 'Left SLF')
# 078. +0.00102 : ('torsion', 'Right Cingulum Cingulate')
# 079. +0.00097 : ('torsion', 'Right Thalamic Radiation')
# 080. +0.00086 : ('torsion', 'Left Thalamic Radiation')
# 081. +0.00085 : ('rd', 'Right Cingulum Cingulate')
# 082. +0.00083 : ('md', 'Left ILF')
# 083. +0.00082 : ('cl', 'Callosum Forceps Minor')
# 084. +0.00081 : ('rd', 'Right IFOF')
# 085. +0.00080 : ('fa', 'Right Thalamic Radiation')
# 086. +0.00079 : ('ad', 'Left Thalamic Radiation')
# 087. +0.00076 : ('cl', 'Left IFOF')
# 088. +0.00073 : ('fa', 'Right IFOF')
# 089. +0.00073 : ('cl', 'Left Arcuate')
# 090. +0.00072 : ('Right Cingulum Hippocampus',)
# 091. +0.00071 : ('volume', 'Left ILF')
# 092. +0.00069 : ('ad', 'Right Arcuate')
# 093. +0.00068 : ('md', 'Left Cingulum Cingulate')
# 094. +0.00067 : ('curvature', 'Callosum Forceps Minor')
# 095. +0.00066 : ('rd', 'Left IFOF')
# 096. +0.00064 : ('rd', 'Right Arcuate')
# 097. +0.00060 : ('torsion', 'Right ILF')
# 098. +0.00058 : ('torsion', 'Right Cingulum Hippocampus')
# 099. +0.00056 : ('torsion', 'Callosum Forceps Major')
# 100. +0.00055 : ('curvature', 'Left SLF')
# 101. +0.00054 : ('fa', 'Left Cingulum Hippocampus')
# 102. +0.00050 : ('rd', 'Right SLF')
# 103. +0.00050 : ('md', 'Left Uncinate')
# 104. +0.00043 : ('curvature', 'Left Thalamic Radiation')
# 105. +0.00043 : ('volume', 'Callosum Forceps Minor')
# 106. +0.00042 : ('cl', 'Left Cingulum Hippocampus')
# 107. +0.00038 : ('volume', 'Left Thalamic Radiation')
# 108. +0.00035 : ('ad', 'Right Cingulum Cingulate')
# 109. +0.00031 : ('curvature', 'Left Cingulum Hippocampus')
# 110. +0.00030 : ('volume', 'Right ILF')
# 111. +0.00028 : ('torsion', 'Left Cingulum Cingulate')
# 112. +0.00025 : ('md', 'Right Cingulum Hippocampus')
# 113. +0.00025 : ('torsion', 'Left Uncinate')
# 114. +0.00022 : ('ad', 'Left Uncinate')
# 115. +0.00021 : ('fa', 'Right Arcuate')
# 116. +0.00021 : ('rd', 'Right ILF')
# 117. +0.00017 : ('volume', 'Right Corticospinal')
# 118. +0.00016 : ('fa', 'Left ILF')
# 119. +0.00009 : ('curvature', 'Right Cingulum Cingulate')
# 120. +0.00008 : ('curvature', 'Right Arcuate')
# 121. +0.00004 : ('cl', 'Left Cingulum Cingulate')
# 122. +0.00002 : ('ad', 'Right IFOF')
# 123. +0.00000 : ('Left Arcuate',)
# 124. -0.00004 : ('fa', 'Right Cingulum Hippocampus')
# 125. -0.00009 : ('curvature', 'Right Corticospinal')
# 126. -0.00011 : ('md', 'Right IFOF')
# 127. -0.00015 : ('cl', 'Left Corticospinal')
# 128. -0.00015 : ('fa', 'Left Cingulum Cingulate')
# 129. -0.00015 : ('cl', 'Right ILF')
# 130. -0.00016 : ('cl', 'Callosum Forceps Major')
# 131. -0.00021 : ('Cingulum Cingulate',)
# 132. -0.00022 : ('volume', 'Right Uncinate')
# 133. -0.00024 : ('md', 'Right SLF')
# 134. -0.00027 : ('fa', 'Callosum Forceps Major')
# 135. -0.00027 : ('ad', 'Left Arcuate')
# 136. -0.00031 : ('curvature', 'Left Cingulum Cingulate')
# 137. -0.00032 : ('volume', 'Right IFOF')
# 138. -0.00036 : ('curvature', 'Left Arcuate')
# 139. -0.00040 : ('ad', 'Right Cingulum Hippocampus')
# 140. -0.00046 : ('curvature', 'Left Corticospinal')
# 141. -0.00048 : ('volume', 'Left IFOF')
# 142. -0.00049 : ('fa', 'Right Cingulum Cingulate')
# 143. -0.00049 : ('md', 'Callosum Forceps Minor')
# 144. -0.00052 : ('Right Cingulum Cingulate',)
# 145. -0.00056 : ('curvature', 'Right Thalamic Radiation')
# 146. -0.00057 : ('fa', 'Left Arcuate')
# 147. -0.00057 : ('rd', 'Callosum Forceps Minor')
# 148. -0.00058 : ('rd', 'Left Uncinate')
# 149. -0.00061 : ('torsion', 'Left Arcuate')
# 150. -0.00066 : ('torsion', 'Right Uncinate')
# 151. -0.00066 : ('rd', 'Right Thalamic Radiation')
# 152. -0.00069 : ('ad', 'Right ILF')
# 153. -0.00071 : ('ad', 'Left Cingulum Cingulate')
# 154. -0.00078 : ('ad', 'Left Corticospinal')
# 155. -0.00079 : ('cl', 'Right Thalamic Radiation')
# 156. -0.00080 : ('volume', 'Right Cingulum Cingulate')
# 157. -0.00082 : ('fa', 'Left Uncinate')
# 158. -0.00084 : ('Cingulum Hippocampus',)
# 159. -0.00087 : ('cl', 'Right Cingulum Hippocampus')
# 160. -0.00094 : ('volume', 'Left Cingulum Hippocampus')
# 161. -0.00105 : ('torsion', 'Right Corticospinal')
# 162. -0.00112 : ('ad', 'Left ILF')
# 163. -0.00113 : ('rd', 'Left Thalamic Radiation')
# 164. -0.00117 : ('ad', 'Callosum Forceps Major')
# 165. -0.00118 : ('volume', 'Left SLF')
# 166. -0.00121 : ('cl', 'Left ILF')
# 167. -0.00121 : ('torsion', 'Left SLF')
# 168. -0.00123 : ('curvature', 'Right IFOF')
# 169. -0.00143 : ('curvature', 'Left Uncinate')
# 170. -0.00149 : ('volume', 'Left Arcuate')
# 171. -0.00156 : ('md', 'Right Uncinate')
# 172. -0.00159 : ('md', 'Left Thalamic Radiation')
# 173. -0.00164 : ('volume', 'Left Uncinate')
# 174. -0.00172 : ('torsion', 'Callosum Forceps Minor')
# 175. -0.00178 : ('rd', 'Callosum Forceps Major')
# 176. -0.00202 : ('cl', 'Left Uncinate')
# 177. -0.00222 : ('rd', 'Right Uncinate')
# 178. -0.00223 : ('torsion', 'Right SLF')
# 179. -0.00231 : ('volume', 'Right SLF')
# 180. -0.00242 : ('Left Cingulum Cingulate',)
# 181. -0.00248 : ('fa', 'Right Uncinate')
# 182. -0.00258 : ('volume', 'Callosum Forceps Major')
# 183. -0.00272 : ('ad', 'Callosum Forceps Minor')
# 184. -0.00274 : ('cl', 'Right Uncinate')
# 185. -0.00300 : ('volume', 'Right Cingulum Hippocampus')
# 186. -0.00386 : ('Uncinate',)
# 187. -0.00432 : ('Right Uncinate',)
# 188. -0.00677 : ('Left Uncinate',)
# 189. -0.00720 : ('Callosum Forceps Major',)

# %% [markdown]
# # Restrict the feature groups to the non-overlapping tract-metric groups

# %%
tract_metric_importances = afqt.get_random_forest_group_scores(
    x, y, tracts_and_metrics, label_sets, type='regressor'
)

# %%
for idx, (f, s) in enumerate(tract_metric_importances):
    print('{idx:03d}. {i:+7.5f} : {f!s}'.format(idx=idx+1, i=s, f=f))

# %% [markdown]
# # Perform cross-validation to select the best $N$ non-overlapping groups

# %%
important_labels = [
    pair[0] for pair in tract_metric_importances
]

extractor = afqt.TopNGroupsExtractor()

rf = RandomForestRegressor(
    n_estimators=100,
)

steps = [
    ('extract', afqt.TopNGroupsExtractor()),
    ('forest', rf)
]

classify_pipeline = Pipeline(steps)

# %% [markdown]
# ## Fit the gridsearch using accuracy

# %%
param_grid = {
    'extract__all_labels': [label_sets],
    'extract__labels_by_importance': [important_labels],
    'extract__top_n': np.arange(10, 161, 10),
    'forest__max_features': [10, 100, None],
    'forest__max_depth': [10, None],
}

scoring = {
    'MSE': 'neg_mean_squared_error',
    'R2': 'r2',
}

forest_regress_cv = GridSearchCV(
    classify_pipeline, param_grid=param_grid,
    scoring=scoring, cv=5, refit='R2',
    verbose=2
)

# %%
forest_regress_cv.fit(x, y)

# %%
forest_regress_cv.best_params_

# %%
forest_regress_cv.best_score_

# %%
y_pred = forest_regress_cv.best_estimator_.predict(x)

# %%
plt.plot(y, color='blue')
plt.plot(y_pred, color='red')
