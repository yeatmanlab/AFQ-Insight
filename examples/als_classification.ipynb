# %% [markdown]
# # Classify ALS status using AFQ-Insight

# %%
import afqinsight as afqi
import matplotlib.pyplot as plt
import numpy as np
import pickle

from mpl_toolkits.mplot3d import Axes3D

from bokeh.io import output_notebook
from bokeh.layouts import row, column, widgetbox
from bokeh.models import BoxSelectTool, HoverTool, Title
from bokeh.palettes import Spectral10
from bokeh.plotting import figure, show, ColumnDataSource

# %matplotlib notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5732619d-26eb-4345-90a9-5dfe6ddeb228">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Load the data

# %%
afq_data = afqi.load_afq_data('../afqinsight/data/classification_data', target_col='class', binary_positive='ALS')

# %%
x, y, groups, cols = afq_data.x, afq_data.y, afq_data.groups, afq_data.columns

# %% [markdown]
# # Naive classification approach
#
# First let's see how a naive classification approach would work, using scikit learn's `Logistic Regression` with an `l1` regularization, akin to the Lasso penalty

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import auc, precision_score, accuracy_score, roc_curve, roc_auc_score

# %%
skf = StratifiedKFold(n_splits=10)

# %%
LR = LogisticRegressionCV(penalty='l1', solver='liblinear')

# %%
y_xval = []
p_xval = []
beta_xval = []
for train_index, test_index in skf.split(x, y):
    x_train = x[train_index]
    x_test = x[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    LR.fit(x_train, y_train)
    beta_xval.append(LR.coef_)
    p_xval.append(LR.predict(x_test))
    y_xval.append(y_test)

# Aggregate the results across folds:
predictions = np.concatenate(p_xval)
ground_truth = np.concatenate(y_xval)

# %%
mean_beta = np.mean(beta_xval, 0).squeeze()

# %%
mean_beta.shape
# Out:
# (16001,)

# %%
feature_dicts = afqi.multicol2dicts(cols, tract_symmetry=False)

# %%
feature_dicts
# Out:
# array([{'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 0},
#        {'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 1},
#        {'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 2},
#        ...,
#        {'metric': 'volume', 'tractID': 'Right Uncinate', 'nodeID': 97},
#        {'metric': 'volume', 'tractID': 'Right Uncinate', 'nodeID': 98},
#        {'metric': 'volume', 'tractID': 'Right Uncinate', 'nodeID': 99}],
#       dtype=object)

# %%
sorted_features = afqi.sort_features(feature_dicts, mean_beta)

sorted_features
# Out:
# [({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 67},
#   -0.1430603492934014),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 37},
#   0.12935561599166762),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 36},
#   -0.12461517237831285),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 81}, -0.12329925244402762),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 43},
#   0.12121069761936931),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 79},
#   0.11622898659220801),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 17},
#   0.11332817950742483),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 39},
#   0.1122192385581269),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 39},
#   0.1052613789154968),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 34},
#   -0.10194849151381416),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 68},
#   -0.0977836906822545),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 46},
#   -0.09681173090283945),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 33},
#   -0.09429821749233021),
#  ({'metric': 'torsion', 'tractID': 'Left ILF', 'nodeID': 64},
#   0.0937969134714027),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 38},
#   -0.09366507869299304),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 88}, -0.09132828095769385),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 96},
#   0.09089061318403978),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 86}, -0.08137207152124833),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 11},
#   0.08065132143116008),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 29},
#   -0.07944279511278687),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 76}, -0.07831371829884029),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 29},
#   -0.07595578595604661),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 23},
#   0.07486985444341504),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 45},
#   -0.07343616514048532),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 88},
#   -0.07253067540023891),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 32},
#   -0.07181564570687934),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 90},
#   0.07060955621094522),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 89}, -0.07013191848776722),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 34},
#   -0.06900073427441324),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 83},
#   0.06589622440822789),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 36},
#   0.06551291302833795),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 0},
#   0.06492081266653076),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 33},
#   -0.06340000541531574),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 30},
#   -0.06233638548396382),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 90},
#   -0.06099700107827881),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 34},
#   -0.05900576303923767),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 38},
#   0.05892331997880264),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 41},
#   -0.058073506476583305),
#  ({'metric': 'rd', 'tractID': 'Left Arcuate', 'nodeID': 6},
#   0.056077126499651644),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 99},
#   -0.055397556013000525),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 97},
#   0.05371230047701518),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 42},
#   -0.052559866318561174),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 71},
#   0.05200173600439957),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 35},
#   -0.05166427601095579),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 3},
#   -0.05151700598802076),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 62},
#   0.05101263164685366),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 35},
#   0.05039139955639153),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 49},
#   -0.050140588006252707),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 48}, 0.0500130297445572),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 3},
#   0.04941004573457846),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 44},
#   0.049388938614966245),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 32},
#   -0.048496682765908725),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 38},
#   -0.04843563483172404),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 33},
#   0.048373460508537705),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 2}, 0.04829393686512857),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 57},
#   0.04816281368566735),
#  ({'metric': 'curvature', 'tractID': 'Right SLF', 'nodeID': 16},
#   0.04759167180045555),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 29},
#   -0.04716131682706326),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 31},
#   0.047147508378265555),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 87},
#   -0.047111895854487336),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 15},
#   0.04677829772319465),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 47},
#   -0.04633147769984058),
#  ({'metric': 'ad', 'tractID': 'Left Corticospinal', 'nodeID': 24},
#   -0.04624148727003905),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 84},
#   0.04587164278153955),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 17},
#   -0.04570176022429147),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 86},
#   0.04560538294145673),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 48},
#   0.04542934042498371),
#  ({'metric': 'torsion', 'tractID': 'Right IFOF', 'nodeID': 7},
#   -0.04539829144851799),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 90},
#   0.04508507763839839),
#  ({'metric': 'curvature', 'tractID': 'Right IFOF', 'nodeID': 59},
#   -0.04441359003818711),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 35},
#   -0.04391324135411302),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 51},
#   0.04368385302105554),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 32},
#   -0.04296253219933074),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 31},
#   -0.04252991535935527),
#  ({'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 40},
#   0.04248939312912217),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 3},
#   -0.042480049363216456),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 2},
#   0.04230384273498574),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 76},
#   -0.041829284955347205),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 89},
#   0.041764732152865636),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 39},
#   -0.04141295841659656),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 75},
#   0.041237778599562507),
#  ({'metric': 'curvature', 'tractID': 'Right Uncinate', 'nodeID': 79},
#   -0.04096121403034149),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 22},
#   0.04075285742687017),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 77},
#   0.04066302454248408),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 84},
#   0.04065120161392409),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 27},
#   -0.04062314162409188),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 70},
#   0.040571809603944235),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 65},
#   -0.04001042306543887),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 66},
#   -0.03999821733421812),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 39},
#   -0.03916843806406807),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 10},
#   -0.03885848513117036),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 49},
#   0.03855775492412882),
#  ({'metric': 'ad', 'tractID': 'Left Arcuate', 'nodeID': 6},
#   0.03855197996076936),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 47},
#   -0.03804036962231243),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 26},
#   -0.0377962958162673),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 43},
#   -0.03773104885034108),
#  ({'metric': 'rd', 'tractID': 'Right IFOF', 'nodeID': 49},
#   -0.03750822719904103),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 30},
#   0.03745669503479467),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 86},
#   -0.037287098805423094),
#  ({'metric': 'volume', 'tractID': 'Callosum Forceps Minor', 'nodeID': 25},
#   -0.03707898405546655),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 11},
#   -0.036931533644848635),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 15},
#   -0.03683475005743468),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 53},
#   0.036538005400315335),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 58},
#   0.03644709392748303),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 46}, 0.03622814306478405),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 28},
#   -0.036079709812050484),
#  ({'metric': 'volume', 'tractID': 'Left IFOF', 'nodeID': 2},
#   0.035641072638412055),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Major', 'nodeID': 96},
#   0.035550449255212224),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 87},
#   0.03546960066826597),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 18},
#   -0.03526927600726641),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 43},
#   -0.035241741080096346),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 37},
#   -0.03514314539574052),
#  ({'metric': 'md', 'tractID': 'Right SLF', 'nodeID': 34},
#   -0.03496939459759007),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 88}, -0.03483219494708613),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 41},
#   0.03479583549698699),
#  ({'metric': 'rd', 'tractID': 'Left Arcuate', 'nodeID': 10},
#   0.03452048862368806),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 43},
#   -0.03451639173675254),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 62},
#   -0.03441565131325866),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 30},
#   0.03436413745189083),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 76},
#   0.034347345767129896),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 67},
#   0.03434154876879649),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 89},
#   -0.03429502075040494),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 15},
#   -0.0342901425226118),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 47},
#   -0.0341986801834403),
#  ({'metric': 'md', 'tractID': 'Left Corticospinal', 'nodeID': 32},
#   0.03409675222092885),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 73},
#   -0.034084065469116784),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 33},
#   -0.03406370950962894),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 3},
#   -0.03384824800995892),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 34},
#   0.0338214903280253),
#  ({'metric': 'md', 'tractID': 'Left ILF', 'nodeID': 43}, 0.03374040659423961),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 41},
#   0.03372153723248481),
#  ({'metric': 'fa', 'tractID': 'Left Arcuate', 'nodeID': 12},
#   -0.03371380160102678),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 3}, 0.03369126443145663),
#  ({'metric': 'rd', 'tractID': 'Left SLF', 'nodeID': 91}, 0.03366829785267633),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 80},
#   0.03364716135204859),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 88},
#   0.033222411206763405),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 50},
#   0.03321083411345322),
#  ({'metric': 'rd', 'tractID': 'Left Uncinate', 'nodeID': 84},
#   0.033047383621536884),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 38},
#   -0.032986734323473765),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 87},
#   -0.03297803210934645),
#  ({'metric': 'volume', 'tractID': 'Right Corticospinal', 'nodeID': 49},
#   0.032949532555124214),
#  ({'metric': 'torsion', 'tractID': 'Right Thalamic Radiation', 'nodeID': 44},
#   0.03287230560888497),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 5},
#   -0.03271217942136888),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 70}, 0.03259068168797204),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 65},
#   -0.03257060298569188),
#  ({'metric': 'curvature', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 55},
#   -0.03253989440615732),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 43},
#   0.032499261300974455),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 7},
#   -0.03234607888180529),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 19},
#   -0.032252463471127334),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Major', 'nodeID': 97},
#   0.032181819803851555),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 42},
#   0.03200745535908024),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 99},
#   0.03197837791676974),
#  ({'metric': 'rd', 'tractID': 'Right Uncinate', 'nodeID': 99},
#   -0.03185580891484838),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 47},
#   0.03185140150386474),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 45},
#   0.03169144471496247),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 13},
#   -0.031596049484225286),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 30},
#   -0.03139898509096095),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 85},
#   -0.031321569031166445),
#  ({'metric': 'cl', 'tractID': 'Right Uncinate', 'nodeID': 5},
#   -0.0312276972983917),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 37},
#   -0.03121572285911269),
#  ({'metric': 'volume', 'tractID': 'Left Thalamic Radiation', 'nodeID': 46},
#   -0.031121856001823895),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 47}, 0.031031885899545426),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 3},
#   0.030972253860690913),
#  ({'metric': 'rd', 'tractID': 'Callosum Forceps Minor', 'nodeID': 89},
#   0.03096587181436334),
#  ({'metric': 'md', 'tractID': 'Right Corticospinal', 'nodeID': 38},
#   0.030936303000676114),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 75},
#   -0.030711703173701754),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 50},
#   0.030423778580337818),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 52}, 0.030319885012554792),
#  ({'metric': 'fa', 'tractID': 'Right Uncinate', 'nodeID': 70},
#   -0.03009004053854577),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 0},
#   -0.03007718427908771),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 47}, 0.029936368871433677),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 53},
#   0.029873199523492617),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 75},
#   -0.02972185341714882),
#  ({'metric': 'curvature', 'tractID': 'Left IFOF', 'nodeID': 12},
#   -0.029696231271434458),
#  ({'metric': 'ad', 'tractID': 'Right SLF', 'nodeID': 36},
#   -0.029583492755394604),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 52},
#   0.029413844064031098),
#  ({'metric': 'torsion', 'tractID': 'Left ILF', 'nodeID': 65},
#   0.029320193088204848),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 18},
#   -0.029263388255891053),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 1}, 0.028931447978353335),
#  ({'metric': 'md', 'tractID': 'Callosum Forceps Major', 'nodeID': 23},
#   -0.028839877385467734),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 2},
#   -0.02879748834663425),
#  ({'metric': 'md', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 8},
#   -0.028724757909363834),
#  ({'metric': 'torsion', 'tractID': 'Right Arcuate', 'nodeID': 87},
#   0.02869967964869281),
#  ({'metric': 'md', 'tractID': 'Left Arcuate', 'nodeID': 40},
#   -0.028655334451746874),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 65},
#   -0.02842863640645496),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 90},
#   -0.02832356441958564),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 18},
#   0.0282195431783337),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 10},
#   0.028123887687371056),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 29},
#   -0.028040679359534283),
#  ({'metric': 'volume', 'tractID': 'Right Arcuate', 'nodeID': 98},
#   -0.028000948057277274),
#  ({'metric': 'ad', 'tractID': 'Left Corticospinal', 'nodeID': 26},
#   -0.027952822350242358),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 40},
#   0.027943920383987277),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 15},
#   -0.02793388952539863),
#  ({'metric': 'rd', 'tractID': 'Right SLF', 'nodeID': 45},
#   -0.02770319544707479),
#  ({'metric': 'torsion', 'tractID': 'Right IFOF', 'nodeID': 68},
#   -0.027663357184728832),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 62},
#   0.02765642903889486),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 52},
#   -0.027655243395190016),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 39},
#   -0.02758086729794814),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 68},
#   0.027523512894372465),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 9},
#   0.02751500419402695),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 44},
#   0.02737929651191951),
#  ({'metric': 'volume', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 74},
#   -0.027230229434520935),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 90},
#   -0.027219081734630113),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 51},
#   -0.027109189343390905),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 52},
#   0.027101048665534692),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 47},
#   -0.02703199612858028),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 29},
#   -0.027024684763823054),
#  ({'metric': 'cl', 'tractID': 'Right IFOF', 'nodeID': 82},
#   -0.026950367488056882),
#  ({'metric': 'torsion', 'tractID': 'Right Uncinate', 'nodeID': 64},
#   -0.026853506085911423),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 31},
#   -0.026852957113219684),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 3},
#   -0.02678735370605765),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 90},
#   -0.026392189618153695),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 0},
#   -0.026333622952160223),
#  ({'metric': 'md', 'tractID': 'Right SLF', 'nodeID': 91}, 0.0262651790201933),
#  ({'metric': 'fa', 'tractID': 'Right Thalamic Radiation', 'nodeID': 1},
#   0.026205648705356677),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 36},
#   -0.026137703223263337),
#  ({'metric': 'curvature', 'tractID': 'Right ILF', 'nodeID': 87},
#   -0.026111760686026796),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 13},
#   -0.025919832849522744),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 67},
#   -0.025876073794221383),
#  ({'metric': 'rd', 'tractID': 'Right ILF', 'nodeID': 25},
#   0.025854382904642446),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 44},
#   -0.02584948193521567),
#  ({'metric': 'md', 'tractID': 'Left Arcuate', 'nodeID': 34},
#   -0.02574522321726968),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 98},
#   0.025667374982585766),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 82},
#   -0.025642842559063538),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 92},
#   -0.025569076309138093),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 69},
#   -0.02552707454686352),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 1}, 0.02552587081031995),
#  ({'metric': 'volume', 'tractID': 'Left Thalamic Radiation', 'nodeID': 92},
#   -0.02552155173851032),
#  ({'metric': 'curvature', 'tractID': 'Callosum Forceps Major', 'nodeID': 97},
#   -0.02541916591550509),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 90},
#   -0.025412369042936124),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 47}, 0.02516305985489927),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 24},
#   -0.025123199769662964),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 34},
#   0.02496583168964642),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 28},
#   -0.02496530747644582),
#  ({'metric': 'md', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 93},
#   0.024869817581681924),
#  ({'metric': 'rd', 'tractID': 'Callosum Forceps Major', 'nodeID': 95},
#   -0.0248464257333805),
#  ({'metric': 'torsion', 'tractID': 'Left Corticospinal', 'nodeID': 98},
#   0.024820955598459198),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 38},
#   -0.024792631969789935),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 6},
#   -0.024755146183052384),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 92},
#   -0.02460156293620919),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 68},
#   -0.02448612232326351),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 54}, 0.024404707602976493),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 19},
#   0.024091573587167188),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 96},
#   0.02396967283113217),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 12},
#   0.023954815716712034),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 11},
#   -0.023696144787202007),
#  ({'metric': 'cl', 'tractID': 'Right IFOF', 'nodeID': 90},
#   -0.023659592782929263),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 79},
#   0.023654594473027726),
#  ({'metric': 'torsion', 'tractID': 'Right Uncinate', 'nodeID': 57},
#   0.02365310944990544),
#  ({'metric': 'cl', 'tractID': 'Right SLF', 'nodeID': 24}, 0.02356614771340685),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 69},
#   -0.023531316583493805),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 51},
#   -0.023475488797970925),
#  ({'metric': 'cl', 'tractID': 'Left Arcuate', 'nodeID': 26},
#   0.023474398012267642),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 80},
#   -0.023438131467228892),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 73},
#   -0.023315380998620395),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 85},
#   0.023292957270113247),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 52},
#   0.023172608635841963),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 16},
#   -0.023084296485278447),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 23},
#   -0.023039217855449115),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 86},
#   -0.023010720056437856),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Major', 'nodeID': 13},
#   0.022954625816332556),
#  ({'metric': 'cl', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 24},
#   0.022890705499800375),
#  ({'metric': 'md', 'tractID': 'Left SLF', 'nodeID': 99}, 0.0228541345310691),
#  ({'metric': 'fa', 'tractID': 'Left IFOF', 'nodeID': 92},
#   -0.022852667817306778),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 12},
#   -0.022798158718423372),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 20},
#   -0.022620110450167936),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 95},
#   -0.022514056927581176),
#  ({'metric': 'ad', 'tractID': 'Right SLF', 'nodeID': 95}, 0.02249355042154911),
#  ({'metric': 'rd', 'tractID': 'Right Arcuate', 'nodeID': 87},
#   -0.022441687543440458),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 81},
#   0.02237382366975348),
#  ({'metric': 'cl', 'tractID': 'Left SLF', 'nodeID': 76}, -0.02227850381390491),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 64},
#   -0.0222159762878475),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 14},
#   -0.022176782565023097),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 19},
#   -0.02213412050913063),
#  ({'metric': 'ad', 'tractID': 'Left Corticospinal', 'nodeID': 27},
#   -0.021988324451301108),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 16},
#   0.0219849199741809),
#  ({'metric': 'fa', 'tractID': 'Right ILF', 'nodeID': 49},
#   -0.021932769935194968),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 60},
#   0.021865340100900927),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 84},
#   -0.02186412147602371),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 37}, -0.02185391419005463),
#  ({'metric': 'md', 'tractID': 'Right ILF', 'nodeID': 99},
#   -0.021852820493873985),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 37},
#   -0.02184437813536752),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 92},
#   -0.02170065248255802),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 84},
#   -0.021686019173356625),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 45},
#   -0.021343714176743873),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 80},
#   -0.02122111063777456),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 47},
#   0.021202201643122833),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 4},
#   -0.021177464257309556),
#  ({'metric': 'ad', 'tractID': 'Left Arcuate', 'nodeID': 74},
#   -0.021167267781922565),
#  ({'metric': 'rd', 'tractID': 'Left SLF', 'nodeID': 85}, 0.021098219116917873),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 61},
#   0.021088509498869396),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 23},
#   0.02100563085166885),
#  ({'metric': 'torsion', 'tractID': 'Left ILF', 'nodeID': 62},
#   0.02100432799928621),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 3},
#   -0.02096404093509057),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 64},
#   -0.02088011764539325),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 39},
#   -0.020818123926153675),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Major', 'nodeID': 62},
#   -0.020808483632989337),
#  ({'metric': 'volume', 'tractID': 'Right Corticospinal', 'nodeID': 24},
#   0.02079614093139896),
#  ({'metric': 'curvature', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 37},
#   -0.02077270431613247),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 30},
#   -0.020743850618647596),
#  ({'metric': 'fa', 'tractID': 'Right Uncinate', 'nodeID': 5},
#   -0.020727930272728408),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 70},
#   0.02070203077689803),
#  ({'metric': 'volume', 'tractID': 'Right Arcuate', 'nodeID': 77},
#   -0.020662072205100756),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 44},
#   0.020643680488971982),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 33},
#   -0.020627516074856113),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 8}, -0.02050730296176257),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 82},
#   -0.020479463162485455),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 80},
#   0.020451898859954583),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 88},
#   -0.02025556040939627),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 58},
#   0.020223553935968697),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 27},
#   -0.02018569071910877),
#  ({'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 61},
#   0.02003473845358087),
#  ({'metric': 'volume', 'tractID': 'Right Thalamic Radiation', 'nodeID': 72},
#   -0.019979150013951067),
#  ({'metric': 'volume', 'tractID': 'Right SLF', 'nodeID': 32},
#   0.019866262243312182),
#  ({'metric': 'curvature',
#    'tractID': 'Right Cingulum Hippocampus',
#    'nodeID': 66},
#   -0.019821919535956255),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 0}, 0.01980653525963639),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 49},
#   0.019778283153506736),
#  ({'metric': 'cl', 'tractID': 'Right IFOF', 'nodeID': 86},
#   0.01972082590517994),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 9}, 0.019697093445224585),
#  ({'metric': 'cl', 'tractID': 'Callosum Forceps Minor', 'nodeID': 37},
#   0.019643601451313775),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 81},
#   -0.019598518261286734),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 48},
#   -0.019589650362031356),
#  ({'metric': 'rd', 'tractID': 'Right ILF', 'nodeID': 27}, 0.01957916347010964),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 56},
#   -0.01956656325327217),
#  ({'metric': 'fa', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 10},
#   0.019508500881484758),
#  ({'metric': 'rd', 'tractID': 'Right Thalamic Radiation', 'nodeID': 5},
#   0.019458653142400563),
#  ({'metric': 'torsion', 'tractID': 'Right Thalamic Radiation', 'nodeID': 15},
#   -0.01945216761615142),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 44},
#   -0.019273858175680683),
#  ({'metric': 'rd', 'tractID': 'Right Uncinate', 'nodeID': 2},
#   0.01925209244698966),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 83}, -0.01921869721797185),
#  ({'metric': 'md', 'tractID': 'Right Thalamic Radiation', 'nodeID': 65},
#   -0.01917608247205849),
#  ({'metric': 'torsion', 'tractID': 'Right Thalamic Radiation', 'nodeID': 45},
#   0.01906184285609834),
#  ({'metric': 'cl', 'tractID': 'Callosum Forceps Minor', 'nodeID': 18},
#   0.019048331106471895),
#  ({'metric': 'md', 'tractID': 'Left Corticospinal', 'nodeID': 38},
#   0.018980761052529237),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 28},
#   -0.018900470187543143),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Minor', 'nodeID': 77},
#   0.018836362178917324),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 95},
#   -0.018829627486305463),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 1},
#   0.01881948102906447),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 88},
#   -0.018727365647503397),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 81},
#   -0.01871844260622344),
#  ({'metric': 'md', 'tractID': 'Left Thalamic Radiation', 'nodeID': 59},
#   -0.01868157112501748),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 0},
#   0.018679057061227865),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 13},
#   -0.01866848476426374),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 75},
#   -0.018589058915840513),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 82},
#   0.018574281670645124),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 91},
#   0.018504596272549932),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 40},
#   -0.018503159803373408),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 85},
#   0.01850068066663766),
#  ({'metric': 'fa', 'tractID': 'Callosum Forceps Major', 'nodeID': 39},
#   0.018466887060483137),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 40},
#   0.01845295017013463),
#  ({'metric': 'md', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 6},
#   -0.018429283212914725),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 83},
#   -0.01842226526022454),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 36}, 0.01840352063141162),
#  ({'metric': 'md', 'tractID': 'Left Thalamic Radiation', 'nodeID': 49},
#   -0.01833765158028883),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 20},
#   -0.01833373409204556),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 53},
#   0.018263998539696763),
#  ({'metric': 'volume', 'tractID': 'Right Arcuate', 'nodeID': 31},
#   -0.018257870890959),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 42},
#   -0.018212809312782154),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 1},
#   -0.018128257566377374),
#  ({'metric': 'fa', 'tractID': 'Right Uncinate', 'nodeID': 51},
#   0.018111174457683326),
#  ({'metric': 'ad', 'tractID': 'Right ILF', 'nodeID': 19},
#   0.017915430421956008),
#  ({'metric': 'torsion', 'tractID': 'Left Arcuate', 'nodeID': 20},
#   -0.01790218984975579),
#  ({'metric': 'ad', 'tractID': 'Left SLF', 'nodeID': 51}, -0.01788391070146818),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 90},
#   -0.017877141355074413),
#  ({'metric': 'md', 'tractID': 'Right Thalamic Radiation', 'nodeID': 86},
#   0.017862436585872953),
#  ({'metric': 'rd', 'tractID': 'Callosum Forceps Major', 'nodeID': 55},
#   -0.017859087942023587),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 62},
#   0.01780173114570509),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 28},
#   -0.017783566734896342),
#  ({'metric': 'fa', 'tractID': 'Right ILF', 'nodeID': 26},
#   -0.01775660451599359),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 68},
#   -0.01774954785548885),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 0},
#   0.017741647525492073),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 56},
#   0.017699773353932986),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 36},
#   -0.01767892786864749),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 46},
#   0.017669874444188684),
#  ({'metric': 'rd', 'tractID': 'Callosum Forceps Major', 'nodeID': 16},
#   -0.017642189036167735),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 62},
#   -0.017595786339339118),
#  ({'metric': 'torsion', 'tractID': 'Right Uncinate', 'nodeID': 0},
#   0.017594026319238405),
#  ({'metric': 'curvature', 'tractID': 'Right SLF', 'nodeID': 17},
#   0.017584158811281524),
#  ({'metric': 'curvature',
#    'tractID': 'Right Cingulum Hippocampus',
#    'nodeID': 88},
#   -0.01756764695726147),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 88},
#   -0.017566892776985588),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 27},
#   -0.017535284732628647),
#  ({'metric': 'torsion', 'tractID': 'Left ILF', 'nodeID': 9},
#   0.01747673613848296),
#  ({'metric': 'volume', 'tractID': 'Right Thalamic Radiation', 'nodeID': 68},
#   -0.017349496748578833),
#  ({'metric': 'torsion', 'tractID': 'Right Thalamic Radiation', 'nodeID': 83},
#   -0.017305909665717555),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 20},
#   -0.01728035529426584),
#  ({'metric': 'md', 'tractID': 'Left Thalamic Radiation', 'nodeID': 60},
#   -0.017249786294208896),
#  ({'metric': 'ad', 'tractID': 'Left Arcuate', 'nodeID': 58},
#   0.017244723985119573),
#  ({'metric': 'md', 'tractID': 'Left SLF', 'nodeID': 21},
#   -0.017223471247171055),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 66},
#   -0.01720685285934429),
#  ({'metric': 'volume', 'tractID': 'Left IFOF', 'nodeID': 46},
#   0.017194884787624827),
#  ({'metric': 'cl', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 75},
#   0.017188566422745286),
#  ({'metric': 'curvature',
#    'tractID': 'Right Cingulum Hippocampus',
#    'nodeID': 57},
#   -0.017107127977227972),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 91},
#   -0.01710195763848278),
#  ({'metric': 'fa', 'tractID': 'Left IFOF', 'nodeID': 68},
#   -0.017081163007700337),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 1},
#   -0.01706844354650803),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 69},
#   0.017037455450690308),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 76},
#   -0.017019104246234918),
#  ({'metric': 'cl', 'tractID': 'Right IFOF', 'nodeID': 18},
#   -0.017008304796967532),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 91},
#   -0.016986859043408353),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 64},
#   -0.016982790433236115),
#  ({'metric': 'volume', 'tractID': 'Right SLF', 'nodeID': 3},
#   0.01694517307638236),
#  ({'metric': 'cl', 'tractID': 'Left Arcuate', 'nodeID': 78},
#   -0.01693033466212752),
#  ({'metric': 'cl', 'tractID': 'Right SLF', 'nodeID': 56},
#   -0.016896373864955135),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 24},
#   -0.01684808708832208),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 6}, 0.016836356442721107),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 91},
#   -0.016829978835991306),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 47},
#   -0.016759234097654667),
#  ({'metric': 'md', 'tractID': 'Right Arcuate', 'nodeID': 52},
#   -0.016683982228892745),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 4},
#   -0.01664758713665056),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 32},
#   0.01664521985839203),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 51},
#   0.016561382421112915),
#  ({'metric': 'ad', 'tractID': 'Left SLF', 'nodeID': 6}, -0.016503637657458596),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 9},
#   -0.01650033016980189),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 30},
#   -0.016499005974395554),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 49}, 0.01647597516048991),
#  ({'metric': 'rd', 'tractID': 'Left Uncinate', 'nodeID': 96},
#   -0.0164465615171347),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 28},
#   -0.016437481263580644),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 91}, -0.01641699315290473),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 19},
#   -0.01640666447456954),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 42},
#   -0.016399375500609076),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 59},
#   0.01639789571210274),
#  ({'metric': 'fa', 'tractID': 'Left IFOF', 'nodeID': 82}, 0.01638721976483997),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 98},
#   0.016280724597068842),
#  ({'metric': 'volume', 'tractID': 'Right SLF', 'nodeID': 56},
#   0.016264552841627117),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 50},
#   0.016258430599511205),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 81},
#   0.01618342022581178),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 87},
#   -0.016182683280750388),
#  ({'metric': 'torsion', 'tractID': 'Left Thalamic Radiation', 'nodeID': 52},
#   -0.016104054259191654),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 21},
#   -0.016088816398357065),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 60},
#   0.016044515906310203),
#  ({'metric': 'md', 'tractID': 'Left Arcuate', 'nodeID': 7},
#   0.015938895929165503),
#  ({'metric': 'volume', 'tractID': 'Right SLF', 'nodeID': 93},
#   0.015881806899889054),
#  ({'metric': 'curvature', 'tractID': 'Left IFOF', 'nodeID': 13},
#   -0.01586517579693878),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 67},
#   -0.015840009514988835),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 52},
#   0.015830774675457036),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 50},
#   0.015825998752450443),
#  ({'metric': 'torsion', 'tractID': 'Left Corticospinal', 'nodeID': 20},
#   -0.015790778459512118),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 91},
#   0.015775482216208208),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 95},
#   -0.01577097251946703),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 64},
#   -0.01576959817951577),
#  ({'metric': 'ad', 'tractID': 'Left Uncinate', 'nodeID': 17},
#   -0.015741841453409226),
#  ({'metric': 'rd', 'tractID': 'Left Arcuate', 'nodeID': 22},
#   -0.0156596882732948),
#  ({'metric': 'ad', 'tractID': 'Left Arcuate', 'nodeID': 75},
#   -0.015652280105673065),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 91},
#   0.015608517702532373),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 94},
#   -0.015578337397500525),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 19},
#   0.015574974587854628),
#  ({'metric': 'torsion', 'tractID': 'Right Uncinate', 'nodeID': 40},
#   0.015516571537334139),
#  ({'metric': 'md', 'tractID': 'Left SLF', 'nodeID': 7}, -0.015488545727406386),
#  ({'metric': 'volume', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 14},
#   0.015484554259193577),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 35},
#   0.01545836989432638),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 46},
#   0.015424235722161278),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 7},
#   0.01541399064964499),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 33},
#   0.01537146229287499),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 22},
#   0.015320420580154865),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 41},
#   -0.015292563874873174),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 24},
#   -0.015283168625127016),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 25},
#   -0.015275005261293828),
#  ({'metric': 'volume', 'tractID': 'Callosum Forceps Major', 'nodeID': 1},
#   -0.015253473348254106),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 82},
#   -0.015202850694161227),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 11},
#   -0.015115807503790107),
#  ({'metric': 'curvature', 'tractID': 'Left Arcuate', 'nodeID': 7},
#   0.015104996699693136),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 86},
#   -0.015103026694259988),
#  ({'metric': 'md', 'tractID': 'Right SLF', 'nodeID': 81},
#   0.015028047641992453),
#  ({'metric': 'ad', 'tractID': 'Left Corticospinal', 'nodeID': 29},
#   -0.015025069952655188),
#  ({'metric': 'ad', 'tractID': 'Right Thalamic Radiation', 'nodeID': 59},
#   -0.015016326281456554),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 29},
#   -0.015013041562791615),
#  ({'metric': 'torsion', 'tractID': 'Left Corticospinal', 'nodeID': 32},
#   -0.014990333705564143),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 85},
#   0.01498828234700074),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 26},
#   -0.01497983137546392),
#  ({'metric': 'torsion', 'tractID': 'Right IFOF', 'nodeID': 87},
#   -0.014965813130847808),
#  ({'metric': 'torsion', 'tractID': 'Left SLF', 'nodeID': 91},
#   -0.014925748370531344),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 48}, 0.014906580172179464),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 47},
#   0.01489377388299033),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 28},
#   -0.014872711996995741),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 5}, 0.014854762690855552),
#  ({'metric': 'curvature', 'tractID': 'Left Corticospinal', 'nodeID': 19},
#   0.014810040211787423),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 70},
#   -0.014798600005351945),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 23},
#   0.014797666188412568),
#  ({'metric': 'curvature', 'tractID': 'Right IFOF', 'nodeID': 4},
#   0.014736611889566747),
#  ({'metric': 'fa', 'tractID': 'Right Arcuate', 'nodeID': 21},
#   -0.014718509888941111),
#  ({'metric': 'rd', 'tractID': 'Left Uncinate', 'nodeID': 30},
#   0.014717441461532765),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 15},
#   -0.014715155225996087),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 22},
#   0.014710944694992109),
#  ({'metric': 'torsion', 'tractID': 'Right Uncinate', 'nodeID': 67},
#   -0.014698077729569617),
#  ({'metric': 'cl', 'tractID': 'Callosum Forceps Minor', 'nodeID': 17},
#   0.014684374001984612),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 5},
#   -0.014670062164354309),
#  ({'metric': 'curvature', 'tractID': 'Callosum Forceps Minor', 'nodeID': 2},
#   -0.014643094757609044),
#  ({'metric': 'volume', 'tractID': 'Left Thalamic Radiation', 'nodeID': 80},
#   -0.014594642032819117),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 16}, 0.01458961091334567),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 93},
#   -0.014574951549635132),
#  ({'metric': 'rd', 'tractID': 'Left Uncinate', 'nodeID': 98},
#   -0.014571428967234517),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 98},
#   0.014546750325595503),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 92},
#   0.0145465738156592),
#  ({'metric': 'curvature', 'tractID': 'Left Corticospinal', 'nodeID': 80},
#   0.01453680330664248),
#  ({'metric': 'curvature', 'tractID': 'Left Corticospinal', 'nodeID': 7},
#   -0.014524466781125716),
#  ({'metric': 'cl', 'tractID': 'Left Arcuate', 'nodeID': 81},
#   -0.014523955454194382),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 37}, 0.014489560740764466),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 48},
#   -0.014444663440036148),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 55},
#   0.014391463587872693),
#  ({'metric': 'ad', 'tractID': 'Right Thalamic Radiation', 'nodeID': 81},
#   0.014390545268863214),
#  ({'metric': 'cl', 'tractID': 'Callosum Forceps Minor', 'nodeID': 77},
#   0.014363892113350724),
#  ({'metric': 'volume', 'tractID': 'Callosum Forceps Minor', 'nodeID': 54},
#   -0.014319417327790776),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 99},
#   0.014288725714779248),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 74},
#   -0.014287857602288095),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 2},
#   -0.01423698209931081),
#  ({'metric': 'torsion', 'tractID': 'Right IFOF', 'nodeID': 86},
#   -0.014187714485493146),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 46},
#   0.014163201377326965),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 59},
#   0.014116911211217064),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 82},
#   0.01409888734317577),
#  ({'metric': 'volume', 'tractID': 'Right ILF', 'nodeID': 73},
#   0.014095199056579605),
#  ({'metric': 'curvature', 'tractID': 'Right IFOF', 'nodeID': 75},
#   0.01407474441303012),
#  ({'metric': 'volume', 'tractID': 'Right Thalamic Radiation', 'nodeID': 91},
#   -0.014066700161441872),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 3},
#   -0.01405450139474082),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 86},
#   -0.014036796211785201),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 44},
#   0.014013344399331083),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 54},
#   -0.014012649704400753),
#  ({'metric': 'ad', 'tractID': 'Right SLF', 'nodeID': 13},
#   -0.013998335791546992),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 13},
#   0.013901567601640356),
#  ({'metric': 'cl', 'tractID': 'Right ILF', 'nodeID': 80},
#   0.013898467273689397),
# ...
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 43},
#   0.009477422090736976),
#  ({'metric': 'fa', 'tractID': 'Right Corticospinal', 'nodeID': 70},
#   -0.009470342747830587),
#  ({'metric': 'ad', 'tractID': 'Right Thalamic Radiation', 'nodeID': 83},
#   0.009455319940460519),
#  ({'metric': 'cl', 'tractID': 'Left IFOF', 'nodeID': 35},
#   0.009434320544358036),
#  ({'metric': 'ad', 'tractID': 'Right Uncinate', 'nodeID': 97},
#   -0.00942819496803032),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 69},
#   0.00942810126091569),
#  ({'metric': 'ad', 'tractID': 'Right IFOF', 'nodeID': 77},
#   -0.009414944940461635),
#  ({'metric': 'volume', 'tractID': 'Left Arcuate', 'nodeID': 73},
#   -0.009408692532413448),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 40},
#   -0.009388113005240183),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 33},
#   -0.009378900376411009),
#  ({'metric': 'cl', 'tractID': 'Left SLF', 'nodeID': 89},
#   -0.009378764694021838),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 47},
#   -0.009369007714680471),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 57},
#   0.009366383971519478),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 8}, 0.009342982272160117),
#  ({'metric': 'curvature', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 7},
#   0.009332151166110794),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 91},
#   -0.009314509190939013),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 43},
#   0.009312875035344328),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 18},
#   -0.009301896845226799),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 2},
#   -0.009301281415777908),
#  ({'metric': 'volume', 'tractID': 'Right ILF', 'nodeID': 42},
#   0.009294073655873859),
#  ({'metric': 'curvature', 'tractID': 'Callosum Forceps Minor', 'nodeID': 79},
#   0.009287420524962528),
#  ({'metric': 'fa', 'tractID': 'Right Uncinate', 'nodeID': 10},
#   -0.009262248452419233),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 55},
#   0.00925723877242272),
#  ({'metric': 'ad', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 91},
#   0.009242180122053509),
#  ({'metric': 'volume', 'tractID': 'Right SLF', 'nodeID': 80},
#   0.009240863216979828),
#  ({'metric': 'cl', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 28},
#   0.009236118761484826),
#  ({'metric': 'rd', 'tractID': 'Right Arcuate', 'nodeID': 35},
#   -0.009227184123854456),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 13},
#   -0.009216958073838611),
#  ({'metric': 'rd', 'tractID': 'Left SLF', 'nodeID': 75}, 0.00917663934535023),
#  ({'metric': 'md', 'tractID': 'Right Thalamic Radiation', 'nodeID': 16},
#   0.009163499202657108),
#  ({'metric': 'curvature', 'tractID': 'Callosum Forceps Minor', 'nodeID': 75},
#   -0.009157086169841337),
#  ({'metric': 'cl', 'tractID': 'Left Arcuate', 'nodeID': 97},
#   -0.009139451647080805),
#  ({'metric': 'cl', 'tractID': 'Left IFOF', 'nodeID': 3}, 0.0091287594367405),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 3},
#   0.009121911378173381),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 79},
#   -0.009109311340461723),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 54},
#   0.009097029981114942),
#  ({'metric': 'md', 'tractID': 'Right Uncinate', 'nodeID': 37},
#   0.009071321887592585),
#  ({'metric': 'cl', 'tractID': 'Left Arcuate', 'nodeID': 29},
#   0.00905476794665783),
#  ({'metric': 'cl', 'tractID': 'Left SLF', 'nodeID': 84},
#   -0.009052612089070164),
#  ({'metric': 'volume', 'tractID': 'Left IFOF', 'nodeID': 23},
#   0.009048567352163089),
#  ({'metric': 'cl', 'tractID': 'Right Corticospinal', 'nodeID': 76},
#   -0.009037970221669798),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 80},
#   0.009020221786768774),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 30}, 0.009019482478172669),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 26},
#   -0.00901730291503787),
#  ({'metric': 'rd', 'tractID': 'Right SLF', 'nodeID': 50},
#   -0.00900064671292886),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 77},
#   -0.008999059273739006),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 63},
#   -0.00898140204566476),
#  ({'metric': 'rd', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 96},
#   0.008974199154441198),
#  ({'metric': 'fa', 'tractID': 'Left Arcuate', 'nodeID': 18},
#   -0.008973977120595129),
#  ({'metric': 'ad', 'tractID': 'Right Uncinate', 'nodeID': 41},
#   0.008971420789475429),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 49},
#   0.008964655019861434),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 38},
#   0.008959322560740963),
#  ({'metric': 'fa', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 4},
#   0.008956771496785799),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 99},
#   0.008954754235656125),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 9},
#   0.008953400329792199),
#  ({'metric': 'fa', 'tractID': 'Left SLF', 'nodeID': 85}, -0.00895014208170877),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 31},
#   -0.008946730489681644),
#  ({'metric': 'curvature', 'tractID': 'Right Thalamic Radiation', 'nodeID': 14},
#   -0.00894080644172551),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 85},
#   -0.008920368621548286),
#  ({'metric': 'cl', 'tractID': 'Right Uncinate', 'nodeID': 10},
#   -0.008915193691094551),
#  ({'metric': 'volume', 'tractID': 'Callosum Forceps Minor', 'nodeID': 66},
#   -0.008906270030651229),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 1},
#   -0.008901544706851805),
#  ({'metric': 'cl', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 38},
#   -0.008895158248290302),
#  ({'metric': 'rd', 'tractID': 'Left Arcuate', 'nodeID': 37},
#   -0.008884949432288094),
#  ({'metric': 'rd', 'tractID': 'Left SLF', 'nodeID': 7}, -0.008880989284217215),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 42}, 0.00885641206258988),
#  ({'metric': 'fa', 'tractID': 'Left ILF', 'nodeID': 89}, -0.00884184201638587),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 55},
#   0.008815192543653344),
#  ({'metric': 'ad', 'tractID': 'Callosum Forceps Minor', 'nodeID': 79},
#   0.00880659531883683),
#  ({'metric': 'curvature',
#    'tractID': 'Left Cingulum Hippocampus',
#    'nodeID': 34},
#   -0.008793725266794287),
#  ({'metric': 'ad', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 22},
#   0.00878356367922457),
#  ({'metric': 'rd', 'tractID': 'Right Arcuate', 'nodeID': 50},
#   -0.00876338351727789),
#  ({'metric': 'rd', 'tractID': 'Right Arcuate', 'nodeID': 58},
#   0.0087415860437255),
#  ({'metric': 'curvature', 'tractID': 'Right IFOF', 'nodeID': 58},
#   -0.008736884158257569),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 93},
#   -0.008735823001774331),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 50},
#   0.008731336799912545),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 22},
#   0.00872607499782662),
#  ({'metric': 'fa', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 25},
#   0.008703372081223033),
#  ({'metric': 'ad', 'tractID': 'Callosum Forceps Major', 'nodeID': 76},
#   -0.008698548155819457),
#  ({'metric': 'fa', 'tractID': 'Left IFOF', 'nodeID': 12},
#   0.008697093871326254),
#  ({'metric': 'curvature', 'tractID': 'Right Arcuate', 'nodeID': 59},
#   -0.00869575769836486),
#  ({'metric': 'cl', 'tractID': 'Left IFOF', 'nodeID': 36},
#   0.008689051596825087),
#  ({'metric': 'torsion', 'tractID': 'Right Corticospinal', 'nodeID': 99},
#   0.008680644801410401),
#  ({'metric': 'fa', 'tractID': 'Left IFOF', 'nodeID': 71},
#   0.008670265230954124),
#  ({'metric': 'fa', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 21},
#   0.008665059296541383),
#  ({'metric': 'md', 'tractID': 'Right SLF', 'nodeID': 46}, 0.00866375694658197),
#  ({'metric': 'rd', 'tractID': 'Right IFOF', 'nodeID': 1},
#   -0.008640685870910336),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 35}, 0.008631686469927763),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 24},
#   0.008619965828498983),
#  ({'metric': 'curvature', 'tractID': 'Callosum Forceps Minor', 'nodeID': 78},
#   -0.008619739015491245),
#  ({'metric': 'fa', 'tractID': 'Right SLF', 'nodeID': 84},
#   -0.00860605502501518),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 57},
#   -0.00859648064375564),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 20},
#   0.008595467491549665),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 66},
#   -0.008592213060384988),
#  ({'metric': 'curvature', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 44},
#   -0.008590422795001103),
#  ({'metric': 'ad', 'tractID': 'Right SLF', 'nodeID': 41},
#   -0.00858813614526854),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Major', 'nodeID': 69},
#   -0.00857284447692248),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 30},
#   0.008539550206542363),
#  ({'metric': 'torsion', 'tractID': 'Left IFOF', 'nodeID': 68},
#   0.008534368992312042),
#  ({'metric': 'torsion', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 62},
#   -0.008530982336434664),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 80},
#   -0.008525656620938512),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 48},
#   0.008521258465970075),
#  ({'metric': 'md', 'tractID': 'Left IFOF', 'nodeID': 93},
#   0.008519296713583742),
#  ({'metric': 'torsion', 'tractID': 'Left Arcuate', 'nodeID': 19},
#   -0.008519230140154186),
#  ({'metric': 'cl', 'tractID': 'Left Thalamic Radiation', 'nodeID': 46},
#   0.00851005492244773),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 38}, 0.008486507331366107),
#  ({'metric': 'volume', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 2},
#   0.008484776170585368),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 48},
#   -0.008465167434298194),
#  ({'metric': 'rd', 'tractID': 'Callosum Forceps Minor', 'nodeID': 6},
#   0.00846302629416901),
#  ({'metric': 'rd', 'tractID': 'Right Thalamic Radiation', 'nodeID': 7},
#   0.008446350132053066),
#  ({'metric': 'fa', 'tractID': 'Left Corticospinal', 'nodeID': 3},
#   0.008445946061849726),
#  ({'metric': 'md', 'tractID': 'Right Corticospinal', 'nodeID': 2},
#   0.008426252896111982),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 35},
#   -0.00841740949191526),
#  ({'metric': 'ad', 'tractID': 'Right Thalamic Radiation', 'nodeID': 86},
#   0.008415695006634688),
#  ({'metric': 'md', 'tractID': 'Left Arcuate', 'nodeID': 3},
#   0.008409569500392098),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 89},
#   0.008406992366556763),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 86},
#   -0.00840625845866028),
#  ({'metric': 'rd', 'tractID': 'Left SLF', 'nodeID': 30},
#   -0.008381526736051675),
#  ({'metric': 'cl', 'tractID': 'Right SLF', 'nodeID': 81},
#   -0.00837417829101144),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 66},
#   0.008368104500825672),
#  ({'metric': 'fa', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 6},
#   0.008366718973397254),
#  ({'metric': 'fa', 'tractID': 'Left Thalamic Radiation', 'nodeID': 39},
#   0.008333732280332762),
#  ({'metric': 'curvature', 'tractID': 'Left ILF', 'nodeID': 57},
#   -0.008333525880066675),
#  ({'metric': 'md', 'tractID': 'Right Cingulum Hippocampus', 'nodeID': 54},
#   0.0083304909638427),
#  ({'metric': 'fa', 'tractID': 'Right Thalamic Radiation', 'nodeID': 46},
#   0.008315981335598275),
#  ({'metric': 'cl', 'tractID': 'Left ILF', 'nodeID': 43}, 0.008296098136352728),
#  ({'metric': 'md', 'tractID': 'Left SLF', 'nodeID': 19},
#   -0.008289240045461246),
#  ({'metric': 'ad', 'tractID': 'Right Thalamic Radiation', 'nodeID': 80},
#   0.008288714636740031),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 0},
#   -0.008285796896553042),
#  ({'metric': 'md', 'tractID': 'Callosum Forceps Major', 'nodeID': 50},
#   -0.008263974801729709),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 19},
#   0.008260616302571782),
#  ({'metric': 'curvature', 'tractID': 'Right SLF', 'nodeID': 15},
#   0.008245438763234672),
#  ({'metric': 'rd', 'tractID': 'Left ILF', 'nodeID': 55}, -0.00824219838023234),
#  ({'metric': 'torsion', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 5},
#   0.008238752528814928),
#  ({'metric': 'md', 'tractID': 'Left Thalamic Radiation', 'nodeID': 88},
#   -0.00823316226476292),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 78},
#   0.008233104297503286),
#  ({'metric': 'md', 'tractID': 'Right Arcuate', 'nodeID': 89},
#   -0.008227777489913853),
#  ({'metric': 'ad', 'tractID': 'Left Thalamic Radiation', 'nodeID': 98},
#   0.008202944897719371),
#  ({'metric': 'md', 'tractID': 'Callosum Forceps Major', 'nodeID': 97},
#   -0.00820288319579624),
#  ({'metric': 'curvature', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 63},
#   -0.008183353111307922),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 77},
#   0.008161351949764726),
#  ({'metric': 'rd', 'tractID': 'Right Corticospinal', 'nodeID': 46},
#   0.008147427362517303),
#  ({'metric': 'torsion', 'tractID': 'Right SLF', 'nodeID': 16},
#   -0.008144800912292206),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 18},
#   -0.008096313952525708),
#  ({'metric': 'curvature', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 91},
#   -0.00809447874488058),
#  ({'metric': 'rd', 'tractID': 'Left Thalamic Radiation', 'nodeID': 12},
#   0.008085356825514653),
#  ({'metric': 'md', 'tractID': 'Right IFOF', 'nodeID': 34},
#   -0.008075026582982132),
#  ({'metric': 'cl', 'tractID': 'Callosum Forceps Minor', 'nodeID': 16},
#   0.008073501258414733),
#  ({'metric': 'curvature', 'tractID': 'Left IFOF', 'nodeID': 26},
#   -0.008064629880488275),
#  ({'metric': 'torsion', 'tractID': 'Left Uncinate', 'nodeID': 99},
#   -0.008056181345766673),
#  ({'metric': 'curvature', 'tractID': 'Left Thalamic Radiation', 'nodeID': 69},
#   0.008047502565476913),
#  ({'metric': 'curvature', 'tractID': 'Right ILF', 'nodeID': 39},
#   0.008047225432912416),
#  ({'metric': 'curvature', 'tractID': 'Left Uncinate', 'nodeID': 31},
#   -0.008034889503335007),
#  ({'metric': 'torsion', 'tractID': 'Right ILF', 'nodeID': 92},
#   0.008024890653524125),
#  ({'metric': 'torsion', 'tractID': 'Callosum Forceps Minor', 'nodeID': 42},
#   0.008016674558878752),
#  ({'metric': 'cl', 'tractID': 'Right Cingulum Cingulate', 'nodeID': 37},
#   0.008006738877753649),
#  ({'metric': 'ad', 'tractID': 'Right Corticospinal', 'nodeID': 30},
#   -0.008006399167648582),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Cingulate', 'nodeID': 38},
#   -0.007996840099006045),
#  ({'metric': 'ad', 'tractID': 'Right Arcuate', 'nodeID': 30},
#   -0.007982766432977715),
#  ({'metric': 'curvature', 'tractID': 'Right Corticospinal', 'nodeID': 31},
#   0.007960210870665394),
#  ({'metric': 'ad', 'tractID': 'Left ILF', 'nodeID': 13}, 0.007952172539845186),
#  ({'metric': 'torsion', 'tractID': 'Left Thalamic Radiation', 'nodeID': 62},
#   0.007938388914527358),
#  ({'metric': 'ad', 'tractID': 'Left SLF', 'nodeID': 18},
#   -0.007909804852241922),
#  ({'metric': 'curvature', 'tractID': 'Right IFOF', 'nodeID': 99},
#   0.007904965385526989),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 75},
#   -0.00789587203918903),
#  ({'metric': 'rd', 'tractID': 'Left Cingulum Hippocampus', 'nodeID': 27},
#   0.007894005267168937),
#  ({'metric': 'rd', 'tractID': 'Left Corticospinal', 'nodeID': 42},
#   0.007882484441652578),
#  ({'metric': 'curvature', 'tractID': 'Left SLF', 'nodeID': 6},
#   -0.007878705153014542),
#  ({'metric': 'volume', 'tractID': 'Left SLF', 'nodeID': 33},
#   0.007862583041311894),
#  ({'metric': 'rd', 'tractID': 'Left Arcuate', 'nodeID': 52},
#   0.00783887169862296),
#  ({'metric': 'cl', 'tractID': 'Right Thalamic Radiation', 'nodeID': 37},
#   0.00783809030502699),
#  ({'metric': 'cl', 'tractID': 'Left Corticospinal', 'nodeID': 43},
#   -0.007837065835218236),
#  ({'metric': 'cl', 'tractID': 'Right Arcuate', 'nodeID': 16},
#   -0.00782811280243679),
#  ...]

# %% [markdown]
# ## Find the optimal feature coefficients $\widehat{\beta}$

# %% [markdown]
# We search for the optimal coefficients using two different classification scores: accuracy and ROC AUC.

# %%
hp_cv_res_acc = afqi.fit_hyperparams_cv(
    x, y, groups, max_evals_per_cv=1000,
    score='accuracy',
    trials_pickle_dir='./cv_trials_cv10_rs42_accuracy',
    verbose=1, random_state=42, clf_threshold=0.5
)

hp_cv_res_auc = afqi.fit_hyperparams_cv(
    x, y, groups, max_evals_per_cv=1000,
    score='roc_auc',
    trials_pickle_dir='./cv_trials_cv10_rs42_rocauc',
    verbose=1, random_state=42, clf_threshold=0.5
)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7a755f60eae8> in <module>()
#       3     score='accuracy',
#       4     trials_pickle_dir='./cv_trials_cv10_rs42_accuracy',
# ----> 5     verbose=1, random_state=42, clf_threshold=0.5
#       6 )
#       7
#
# ~/source/AFQ-Insight/afqinsight/insight.py in fit_hyperparams_cv(x, y, groups, bias_index, n_splits, n_repeats, max_evals_per_cv, loss_type, score, trials_pickle_dir, mongo_handle, random_state, verbose, clf_threshold)
#     682             mongo_handle=mongo_handle,
#     683             mongo_exp_key=mongo_exp_key,
# --> 684             save_trials_pickle=pickle_name
#     685         )
#     686
#
# ~/source/AFQ-Insight/afqinsight/insight.py in fit_hyperparams(x, y, groups, bias_index, max_evals, loss_type, score, trials, mongo_handle, mongo_exp_key, save_trials_pickle)
#     509
#     510     best = fmin(hp_objective, hp_space, algo=tpe.suggest,
# --> 511                 max_evals=max_evals, trials=trials)
#     512
#     513     if mongo_handle is None and save_trials_pickle is not None:
#
# ~/.virtualenvs/afq/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     305             verbose=verbose,
#     306             catch_eval_exceptions=catch_eval_exceptions,
# --> 307             return_argmin=return_argmin,
#     308         )
#     309
#
# ~/.virtualenvs/afq/lib/python3.6/site-packages/hyperopt/base.py in fmin(self, fn, space, algo, max_evals, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin)
#     633             pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     634             catch_eval_exceptions=catch_eval_exceptions,
# --> 635             return_argmin=return_argmin)
#     636
#     637
#
# ~/.virtualenvs/afq/lib/python3.6/site-packages/hyperopt/fmin.py in fmin(fn, space, algo, max_evals, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin)
#     312
#     313     domain = base.Domain(fn, space,
# --> 314                          pass_expr_memo_ctrl=pass_expr_memo_ctrl)
#     315
#     316     rval = FMinIter(algo, domain, trials, max_evals=max_evals,
#
# ~/.virtualenvs/afq/lib/python3.6/site-packages/hyperopt/base.py in __init__(self, fn, expr, workdir, pass_expr_memo_ctrl, name, loss_target)
#     784         before = pyll.dfs(self.expr)
#     785         # -- raises exception if expr contains cycles
# --> 786         pyll.toposort(self.expr)
#     787         vh = self.vh = VectorizeHelper(self.expr, self.s_new_ids)
#     788         # -- raises exception if v_expr contains cycles
#
# ~/.virtualenvs/afq/lib/python3.6/site-packages/hyperopt/pyll/base.py in toposort(expr)
#     713         G.add_edges_from([(n_in, node) for n_in in node.inputs()])
#     714     order = nx.topological_sort(G)
# --> 715     assert order[-1] == expr
#     716     return order
#     717
#
# TypeError: 'generator' object is not subscriptable

# %% [markdown]
# Let's examine the regularization parameters for each CV split.

# %%
[(r.alpha1, r.alpha2) for r in hp_cv_res_auc]

# %% [markdown]
# And look at the classification scores achieved.

# %%
def print_results_summary(hp_cv_results):
    template = '{stat:15s} {mean:7.5g} ({var:7.5g})'
    test = [r.test for r in hp_cv_results]
    train = [r.train for r in hp_cv_results]
    test_acc = [t.accuracy for t in test]
    test_auc = [t.auc for t in test]
    test_aps = [t.avg_precision for t in test]
    train_acc = [t.accuracy for t in train]
    train_auc = [t.auc for t in train]
    train_aps = [t.avg_precision for t in train]

    print('Statistic         mean   (variance)')
    print('--------------  ------- ------------')
    print(template.format(stat='test accuracy', mean=np.mean(test_acc), var=np.var(test_acc)))
    print(template.format(stat='test AUC', mean=np.mean(test_auc), var=np.var(test_auc)))
    print(template.format(stat='test avg prec', mean=np.mean(test_aps), var=np.var(test_aps)))
    print(template.format(stat='train accuracy', mean=np.mean(train_acc), var=np.var(train_acc)))
    print(template.format(stat='train AUC', mean=np.mean(train_auc), var=np.var(train_auc)))
    print(template.format(stat='train avg prec', mean=np.mean(train_aps), var=np.var(train_aps)))

# %%
print_results_summary(hp_cv_res_acc)

# %%
print_results_summary(hp_cv_res_auc)

# %%
p = figure(plot_width=700, plot_height=700, toolbar_location='above')
p.title.text = 'Classification probabilities for each CV split'
p.add_layout(
    Title(text='Click on legend entries to hide/show the corresponding lines',
          align="left"), 'right'
)

names = ['cv_idx = {i:d}'.format(i=i) for i in range(len(hp_cv_res_auc))]

hover = HoverTool(
    tooltips=[("index", "$index"),],
    mode='vline',
)
hover.point_policy = 'snap_to_data'
hover.line_policy = 'nearest'

for res, color, name in zip(hp_cv_res_auc, Spectral10, names):
    p.line(np.arange(len(y)), afqi.insight._sigmoid(x.dot(res.beta_hat)),
           line_width=2, color=color, alpha=0.8, legend=name)

p.line(np.arange(len(y)), y, line_width=3, alpha=0.8, legend='ground truth')
p.line(np.arange(len(y)), 0.5 * np.ones(len(y)), 
       line_width=2, line_dash='dashed', alpha=0.8, legend='threshold')
p.add_tools(hover)
p.legend.location = 'top_right'
p.legend.click_policy = 'hide'

show(p)

# %% [markdown]
# Using the hover tool on the chart above, we can see that subjects 05, 07, 08, 16, 19, 30, 32, 35, 36 are all hard to classify (they are consistently closer to the classification threshold of 0.5). We should fire up the AFQ browser and look at how these subjects compare to the rest of the subjects in their group.
#
# Here are links to a running instance of AFQ-Browser with the hard to classify subjects:
# - [False negatives](https://yeatmanlab.github.io/Sarica_2017/?table[prevSort][count]=2&table[prevSort][order]=ascending&table[prevSort][key]=&table[sort][count]=2&table[sort][order]=ascending&table[sort][key]=class&table[selectedRows][subject_005]=true&table[selectedRows][subject_007]=true&table[selectedRows][subject_008]=true&table[selectedRows][subject_016]=true&table[selectedRows][subject_019]=true&table[selectedRows][subject_030]=false&table[selectedRows][subject_032]=false&table[selectedRows][subject_035]=false&table[selectedRows][subject_036]=false&plots[checkboxes][right-corticospinal]=true&plots[zoom][rd][scale]=1&plots[zoom][rd][translate][0]=-3&plots[zoom][rd][translate][1]=-21&plots[zoom][fa][scale]=2.1140360811227614&plots[zoom][fa][translate][0]=-27.244995845837778&plots[zoom][fa][translate][1]=-106.10468474511174&plots[plotKey]=fa&plots[errorType]=stderr&plots[lineOpacity]=0.09355440414507772)
# - [False positives](https://yeatmanlab.github.io/Sarica_2017/?table[prevSort][count]=2&table[prevSort][order]=ascending&table[prevSort][key]=&table[sort][count]=2&table[sort][order]=ascending&table[sort][key]=class&table[selectedRows][subject_005]=false&table[selectedRows][subject_007]=false&table[selectedRows][subject_008]=false&table[selectedRows][subject_016]=false&table[selectedRows][subject_019]=false&table[selectedRows][subject_030]=true&table[selectedRows][subject_032]=true&table[selectedRows][subject_035]=true&table[selectedRows][subject_036]=true&plots[checkboxes][right-corticospinal]=true&plots[zoom][rd][scale]=1&plots[zoom][rd][translate][0]=-3&plots[zoom][rd][translate][1]=-21&plots[zoom][fa][scale]=2.1140360811227614&plots[zoom][fa][translate][0]=-27.244995845837778&plots[zoom][fa][translate][1]=-106.10468474511174&plots[plotKey]=fa&plots[errorType]=stderr&plots[lineOpacity]=0.09355440414507772)

# %% [markdown]
# Let's sort the features by their importance

# %%
feature_dicts = afqi.multicol2dicts(cols, tract_symmetry=False)

mean_beta = np.mean(np.array(
    [res.beta_hat for res in hp_cv_res_auc]
), axis=0)

sorted_features = afqi.sort_features(feature_dicts, mean_beta)

sorted_features

# %% [markdown]
# It's nice to see the top few features in a sorted list, but let's plot the features to get a feel for their distributions

# %%
beta_hats = afqi.beta_hat_by_groups(mean_beta, columns=cols, drop_zeros=True)

# %%
def plot_betas(beta_hat, all_metrics, ecdf=False):
    ps = []

    colors = {}
    for idx, metric in enumerate(all_metrics):
        colors[metric] = Spectral10[idx]
        
    for idx, tract in enumerate(beta_hat.keys()):
        ps.append(figure(plot_width=750, plot_height=250, toolbar_location='right'))
        ps[idx].title.text = tract

        for metric in beta_hat[tract].keys():
            b = beta_hat[tract][metric]
            if not all(b == 0):
                if ecdf:
                    cdf = afqi.utils.ecdf(b)
                    ps[idx].circle(cdf.x, cdf.y,
                                   size=5, color=colors[metric],
                                   alpha=0.8, legend=metric)
                else:
                    ps[idx].line(np.arange(len(b)), b,
                                 line_width=4, color=colors[metric],
                                 alpha=0.8, legend=metric)

        ps[idx].legend.location = 'bottom_right'
        ps[idx].legend.click_policy = 'hide'

    show(column(ps))

# %% [markdown]
# First let's plot the coefficients themselves

# %%
plot_betas(beta_hat=beta_hats, all_metrics=cols.levels[cols.names.index('metric')])

# %% [markdown]
# Now let's plot the empirical cumulative distribution function (ECDF) of each set of coefficients.

# %%
plot_betas(beta_hat=beta_hats, all_metrics=cols.levels[cols.names.index('metric')], ecdf=True)

# %% [markdown]
# ## Output coefficients to AFQ-Browser CSV format

# %%
afqi.output_beta_to_afq(
    beta_hat=mean_beta,
    columns=cols,
    workdir_in='../afqinsight/data/classification_data',
    workdir_out='../afqinsight/data_with_weights',
    scale_beta=True
)
